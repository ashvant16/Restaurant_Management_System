# %% [markdown]
# <a href="https://colab.research.google.com/github/ashvant16/Restaurant_Management_System/blob/main/GROUP_8_Restaurant_Management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import clear_output

def clearscreen():
  for i in range(10):
    clear_output(wait=True)
  print()

name=[]                       # Names of diners with date and time
date=[]                       # Contains date of a single day
dates={}                      # Contains every date with list of that date's times

item1=['Regular Tea\t','Masala Tea\t','Coffee\t\t','Cold Drink\t','Bread Butter\t','Bread Jam\t','Veg. Sandwich\t','Non-Veg Sandwich','Grilled Cheese\t','Beef Burger\t','Tomato Soup\t','Veg Hot & Sour\t','Veg Manchow Soup','Chicken Hot & Sour','Chicken Manchow Soup','Matar Mushroom\t','Kadai Paneer\t','Chilli Paneer\t','Palak Paneer\t','Chicken Coconut Curry','Chilli Chicken\t','Kadai Chicken\t','Butter Chicken\t']
item1_price=[20.00,20.00,20.00,30.00,30.00,30.00,50.00,100.00,80.00,180.00,110.00,110.00,110.00,130.00,130.00,110.00,110.00,120.00,120.00,140.00,140.00,150.00,160.00]
item2=['Pepper Beef\t','Beef Curry\t','Prawn Curry\t','Fish Pollichathu','Fish Coconut Curry','Chapati\t\t','Butter Roti\t','Tandoori Roti\t','Butter Naan\t','Plain Rice\t','Ghee Rice\t','Egg Fried Rice\t','Veg Fried Noodles','Sambhar Vada\t','Ghee Roast Dosa\t','Masala Dosa\t','Appam & Egg Curry','Porotta & Beef Curry','Vanilla\t\t','Chocolate\t','Strawberry\t','Butter Scotch\t']
item2_price=[150.00,150.00,170.00,160.00,160.00,15.00,15.00,20.00,20.00,90.00,90.00,110.00,110.00,50.00,60.00,70.00,120.00,140.00,40.00,40.00,40.00,40.00]

bill_output=["Dish","Rate","Quantity","Amount"]

questions=["\t\t1. What was the reason for your visit?\t","\t\t2. How would you rate the food?\t\t","\t\t3. Were the staff friendly and helpful?\t","\t\t4. What can we do to improve our services?"]

a1=["Birthday","Anniversary"]
a2=["Excellent!","4/5"]
a3=["The staff were extremely kind and attentive","Indeed"]
a4=["Please add more options for vegetarians","Nothing!"]
answers={1:a1,2:a2,3:a3,4:a4}


def home():                                              # HOME PAGE FUNCTION
  print("\n\t\t\t\t\t\t WELCOME TO ORION!")
  print("\t\t\t","-"*85)
  print()
  print("\t\t\t1. TABLE RESERVATION     \t\t\t| A few feedback from our previous diners:")
  print("\t\t\t2. ORDER NOW             \t\t\t| Q. How would you rate the food?")
  print("\t\t\t3. CUSTOMER FEEDBACK    \t\t\t| -->",a2[0],", ",a2[1])
  print("\t\t\t4. CANCEL RESERVATION    \t\t\t| Q. Were the staff friendly and helpful?")
  print("\t\t\t5. CHANGE RESERVATION   \t\t\t| -->",a3[0],", ",a3[1])
  print("\t\t\t6. EXIT")
  x=input("\n\n\t\t\tEnter your choice")
  if x=='1':
      clearscreen()
      reserve()
  elif x=="2":
      clearscreen()
      view_menu()
  elif x=='3':
      clearscreen()
      feedback()
  elif x=='6':
      clearscreen()
      main()
  elif x=='4':
      clearscreen()
      cancel_res()
  elif x=="5":
    clearscreen()
    change_res()
  else:
      cl=input("\t\tWrong Entry! Click Enter to try again.")
      clearscreen()
      home()


def datecheck(d):                 # CHECKS IF DATE IS VALID
  if d[2]==2023:
    if d[1]!=0 and d[1]<=12:      # CHECKS IF MONTH IS VALID
      if d[1]==2:                 # CHECKS IF MONTH IS FEBRUARY
        if d[2]%4==0:             # CHECKS IF YEAR IS LEAP YEAR OR NOT
          if d[0]<=29:
            return True
        elif d[0]<29:
            return True
        else:
          print("\t\t\tINVALID DATE!\n")
          a=input("\t\tEnter any key to continue")
          clearscreen()
          reserve()
      elif d[1]<=7 and d[1]%2==0 and d[0]<=30:  #CHECKS IF NO. OF DAYS ARE VALID
           return True
      elif d[1]<=7 and d[1]%2!=0 and d[0]<=31:
            return True
      elif d[1]>7 and d[1]%2==0 and d[0]<=31:
          return True
      elif d[1]>7 and d[1]%2!=0 and d[0]<=30:
          return True
      else:
        print("\t\t\tINVALID DATE!\n")
        a=input("\t\tEnter any key to continue")
        clearscreen()
        reserve()
    else:
        print("\t\t\tINVALID DATE!\n")
        a=input("\t\tEnter any key to continue")
        clearscreen()
        reserve()
  else:
        print("\t\t\tINVALID DATE!\n")
        a=input("\t\tEnter any key to continue")
        clearscreen()
        reserve()


def reserve():    # BASIC RESERVATION FUNCTION
  while 1:
    x=""
    n=input("\n\t\tName: ")
    time=input("\t\tTime (hr:min): ")
    da=input("\t\tDate (dd/mm/yyyy): ")
    phno=input("\t\tPhone Number (10 digit): ")
    no=input("\t\tNumber of Diners: ")
    if n!="" and time!='' and phno!="" and len(phno)==10 and da!="" and no!="":
      date=da.split('/')
      date[0]=int(date[0])
      date[1]=int(date[1])
      date[2]=int(date[2])

      if datecheck(date):
       date[0]=str(date[0])
       date[1]=str(date[1])
       date[2]=str(date[2])
       da=date[0]+"/"+date[1]+"/"+date[2]
       if res_check(da,time):
        x=n+"_"+da+"_"+time+"_"+phno+"_"+no
        name.append(x)
        if da in dates:
          dates[da]=dates[da]+"_"+time
        else:
          dates[da]=time
        clearscreen()
        print("\n\t\t\tBOOKED!!!!")
        st=name[len(name)-1].split("_")
        print("\t\t ",st[0]," on ",st[1]," at ",st[2],"!\n\n")
        a=input("\t\tEnter any key to continue")
        clearscreen()
        home()
      break
    elif len(phno)!=10and phno!="":
      print("\t\tWrong input for phone number!")
      a=input("\t\tEnter any key to continue")
      clearscreen()
      reserve()
    else:
      print("\t\t\tCannot be empty!\n")
      a=input("\t\tEnter any key to continue")
      clearscreen()
      reserve()

    home()

def res_check(x,t):             # CHECKS IF RESERVATIONS FALL ON THE SAME DAY AND TIME
  if x in dates:
    for i in dates.keys():
      if x==i:
        a=dates[x]
        a=a.split("_")
        if t in a:
          print("\t\t\t\nThis hour has already been reserved.\n")
          a=input("\t\tEnter any key to go back.")
          clearscreen()
          reserve()
        return True
  else:
    return True


def cancel_res():                 # TO CANCEL RESERVATIONS
  flag=0
  a=input("\t\tCancelling reservations will cost ₹250. Are you sure you want to continue? (Y/N)\t")
  if a=="y" or a=="Y":
    n=input("\t\tEnter your name:\t")
    d=input("\t\tEnter the date(dd/mm/yy):\t")
    date=d.split('/')
    date[0]=str(int(date[0]))
    date[1]=str(int(date[1]))
    date[2]=str(int(date[2]))
    d=date[0]+"/"+date[1]+"/"+date[2]
    t=input("\t\tEnter the time(hr:min):\t")
    x=n+"_"+d+"_"+t
    for i in name:
        if x in i:
          flag=1
          name.remove(i)

          for j in dates.keys():
            a=dates[j]
            a=a.split('_')
            st=""
            if len(a)>1:
              for k in a:
                if k!=t:
                  st=st+"_"+k
                  dates[j]=st
                else:
                  dates.pop(j)
                  dates[j]=st

            else:
              dates.pop(j)
              break

    if flag==1:
      print("\n\t\tDONE! Your Reservation has been removed! ")
      fee=input("\t\tClick Enter to pay ₹250 and return to the main menu:\t")
      clearscreen()
      home()
    else:
      print("\n\t\tNo reservation found!")
      cl=input("\t\tClick Enter to go back.")
      clearscreen()
      cancel_res()
  else:
    clearscreen()
    home()

def change_res():                               # CHANGE RESERVATIONS
  print("\t\tWhat would you like to change?")
  print("\t\t1. Name")
  print("\t\t2. Date")
  print("\t\t3. Time")
  print("\t\t4. Phone Number")
  print("\t\t5. Number of Diners")
  print("\t\t6. Exit")
  x=input("\n\t\tEnter Choice")
  if x=='1':                                          # NAME
    n=input("\t\tPlease enter your name:\t")
    for i in name:
      if n in i:
        ind=name.index(i)
        a=name.pop(ind)
        a=a.split("_")
        n=input("\t\tEnter your name:\t")
        a[0]=n
        y=a[0]+"_"+a[1]+"_"+a[2]+"_"+a[3]+"_"+a[4]
        name.append(y)
        print("\t\tChanged!")
        cl=input("\n\t\tClick Enter to go back.")
        clearscreen()
        home()
        break
      else:
        cl=input("\t\tWrong Input!\n\t\tClick Enter to go back.")
        clearscreen()
        change_res()
  elif x=='4':                                        # PH NO:
    n=input("\t\tPlease enter your name:\t")
    for i in name:
      if n in i:
        ind=name.index(i)
        a=name.pop(ind)
        a=a.split("_")
        n=input("\t\tEnter your Phone number:\t")
        a[3]=n
        y=a[0]+"_"+a[1]+"_"+a[2]+"_"+a[3]+"_"+a[4]
        name.append(y)
        print("\t\tChanged!")
        cl=input("\n\t\tClick Enter to go back.")
        clearscreen()
        home()
        break
      else:
        cl=input("\t\tWrong Input!\n\t\tClick Enter to go back.")
        clearscreen()
        change_res()
  elif x=='5':                                      # NO OF DINERS
    n=input("\t\tPlease enter your name:\t")
    for i in name:
      if n in i:
        ind=name.index(i)
        a=name.pop(ind)
        a=a.split("_")
        n=input("\t\tEnter the number of diners:\t")
        a[4]=n
        y=a[0]+"_"+a[1]+"_"+a[2]+"_"+a[3]+"_"+a[4]
        name.append(y)
        print("\t\tChanged!")
        cl=input("\n\t\tClick Enter to go back.")
        clearscreen()
        home()
        break
      else:
        cl=input("\t\tWrong Input!\n\t\tClick Enter to go back.")
        clearscreen()
        change_res()
  elif x=='2':                                      # DATE
      n=input("\t\tPlease enter your name:\t")
      for i in name:
        if n in i:
          ind=name.index(i)
          a=name.pop(ind)
          a=a.split("_")
          dat=a[1]
          n=input("\t\tEnter new date:\t")
          date=n.split('/')
          date[0]=str(int(date[0]))
          date[1]=str(int(date[1]))
          date[2]=str(int(date[2]))
          n=date[0]+"/"+date[1]+"/"+date[2]
          a[1]=n
          y=a[0]+"_"+a[1]+"_"+a[2]+"_"+a[3]+"_"+a[4]
          name.append(y)
          for j in dates.keys():
            if dat in j:
              org=dates[j]
              dates.pop(j)
              dates[a[1]]=org
          print("\t\tChanged!")
          cl=input("\n\t\tClick Enter to go back.")
          clearscreen()
          home()
          break
        else:
          cl=input("\t\tWrong Input!\n\t\tClick Enter to go back.")
          clearscreen()
          change_res()
  elif x=='3':                                      # TIME
      n=input("\t\tPlease enter your name:\t")
      s=""
      for i in name:
        if n in i:
          ind=name.index(i)
          a=name.pop(ind)
          a=a.split("_")
          tim=a[2]
          n=input("\t\tEnter new time:\t")
          a[2]=n
          y=a[0]+"_"+a[1]+"_"+a[2]+"_"+a[3]+"_"+a[4]
          name.append(y)
          for j in dates.keys():
            if tim in dates[j]:
              org=dates[j]
              org=org.split("_")
              if len(org)==1:
                dates.pop(j)
                dates[j]=a[2]
              else:
                for k in org:
                  if tim==k:
                     org.remove(k)
                     org.append(a[2])
                     s=s+"_"+a[2]
                     dates[j]=s
                  else:
                    s=s+"_"+k
                    dates[j]=s

          print("\t\tChanged!")
          cl=input("\n\t\tClick Enter to go back.")
          clearscreen()
          home()
          break
        else:
          cl=input("\t\tWrong Input!\n\t\tClick Enter to go back.")
          clearscreen()
          change_res()
  else:
    clearscreen()
    home()


def feedback():                       # FEEDBACK FUNCTION
  for i in range(4):
    a=input(questions[i])
    if i==0:
      a1.append(a)
    elif i==1:
      a2.append(a)
    elif i==2:
      a3.append(a)
    else:
      a4.append(a)
    feedback1()
  clearscreen()
  print("\n\t\t THANK YOU FOR YOUR TIME!")
  a=input("\n\t\tEnter any key to exit:\t")
  clearscreen()
  home()

def feedback1():
  answers[1]=a1
  answers[2]=a2
  answers[3]=a3
  answers[4]=a4


def menu():
            print("-------------------------------------------------------------------------")
            print("                              ORION")
            print("-------------------------------------------------------------------------")
            print("                            Menu Card")
            print("-------------------------------------------------------------------------")
            print("\n BEVERAGES and SANDWICHES               26 Prawn Curry............ 170.00")
            print("----------------------------------      27 Fish Pollichathu....... 160.00")
            print(" 1  Regular Tea............. 20.00      28 Fish Coconut Curry..... 160.00")
            print(" 2  Masala Tea.............. 20.00")
            print(" 3  Coffee.................. 20.00      BREADS")
            print(" 4  Cold Drink.............. 30.00     ----------------------------------")
            print(" 5  Bread Butter............ 30.00      29 Chapati................. 15.00")
            print(" 6  Bread Jam............... 30.00      30 Butter Roti............. 15.00")
            print(" 7  Veg. Sandwich........... 50.00      31 Tandoori Roti........... 20.00")
            print(" 8  Non-Veg Sandwich....... 100.00      32 Butter Naan............. 20.00")
            print(" 9  Grilled Cheese.......... 80.00")
            print(" 10 Beef Burger............ 180.00      RICE/NOODLES")
            print("                                       ----------------------------------")
            print(" SOUPS                                  33 Plain Rice.............. 90.00")
            print("----------------------------------      34 Ghee Rice............... 90.00")
            print(" 11 Tomato Soup............ 110.00      35 Egg Fried Rice......... 110.00")
            print(" 12 Veg Hot & Sour......... 110.00      36 Veg Fried Noodles...... 110.00")
            print(" 13 Veg Manchow Soup....... 110.00")
            print(" 14 Chicken Hot & Sour..... 130.00      SOUTH INDIAN")
            print(" 15 Chicken Manchow Soup... 130.00     ----------------------------------")
            print("                                        37 Sambhar Vada............ 50.00")
            print(" MAIN COURSE                            38 Ghee Roast Dosa......... 60.00")
            print("----------------------------------      39 Masala Dosa............. 70.00")
            print(" 16 Matar Mushroom......... 110.00      40 Appam & Egg Curry...... 120.00")
            print(" 17 Kadai Paneer........... 110.00      41 Porotta & Beef Curry... 140.00")
            print(" 18 Chilli Paneer.......... 120.00")
            print(" 19 Palak Paneer........... 120.00")
            print(" 20 Chicken Coconut Curry.. 140.00      ICE CREAM")
            print(" 21 Chilli Chicken......... 140.00     ----------------------------------")
            print(" 22 Kadai Chicken.......... 150.00      42 Vanilla................. 40.00")
            print(" 23 Butter Chicken......... 160.00      43 Chocolate............... 40.00")
            print(" 24 Pepper Beef............ 150.00      44 Strawberry.............. 40.00")
            print(" 25 Beef Curry............. 150.00      45 Butter Scotch........... 40.00")


def view_menu():
            cust_total=0
            menu()
            a=input("\n\t\tWould you like to order now? (Y/N)\t")
            if a=='y' or a=='Y':
              print("\t\tClick Enter to go back.\n\t\tTo CANCEL any dish enter 100\n\t\tEnter 0 to finish ordering.")
              x=input("\n\t\tEnter the item number to order a dish:\t")
              if x!="":
                x=int(x)
                cust_order=[]
                cust_order_no=[]
                cust_q=[]
                cust_bill_1=[]
                cust_bill_2=[]
                cust_total=0
                while x!=0:
                  if x<=23:
                    y=int(input("\t\tEnter quantity:\t"))
                    cust_q.append(y)
                    cust_order_no.append(x)
                    cust_order.append(item1[x-1])
                    cust_bill_1.append(item1_price[x-1])
                    cust_bill_2.append(item1_price[x-1]*y)
                    cust_total+=y*item1_price[x-1]
                  elif x>23 and x<=45:
                    y=int(input("\t\tEnter quantity:\t"))
                    cust_q.append(y)
                    cust_order_no.append(x)
                    cust_order.append(item2[x-24])
                    cust_bill_1.append(item2_price[x-24])
                    cust_bill_2.append(item2_price[x-24]*y)
                    cust_total+=y*item2_price[x-24]

                  elif x==100:                                        # CANCELLING ITEMS
                    clearscreen()
                    if cust_order:                                    # IF CUSTOMER ORDER IS NOT EMPTY

                      print("{}\t\t\t\t\t{}\t\t{}\t{}".format("Item No.",bill_output[1],bill_output[2],bill_output[3]))
                      for i in range(len(cust_order)):
                        print("{}\t{}\t\t\t₹{}\t\t{}\t\t₹{}".format(cust_order_no[i],cust_order[i],cust_bill_1[i],cust_q[i],cust_bill_2[i]))
                      rem=int(input("\n\t\tEnter item number of item you want to remove:\t"))
                      if rem>0 and rem<24:
                          if item1[rem-1] in cust_order:                 # IF THE GIVEN ITEM IS PRESENT IN ORDER
                            rem_index=cust_order.index(item1[rem-1])
                            cust_order.remove(item1[rem-1])
                            q=cust_q.pop(rem_index)
                            cust_order_no.pop(rem_index)
                            cust_bill_1.pop(rem_index)
                            cust_bill_2.pop(rem_index)
                            cust_total-=q*item1_price[rem-1]
                            print("\t\tRemoved!")
                          else:
                            print("\t\tThis dish is not in your order! Enter 100 to try again.")
                      elif rem>23 and rem<=45:
                          if item2[rem-24] in cust_order:                 # IF THE GIVEN ITEM IS PRESENT IN ORDER
                            rem_index=cust_order.index(item2[rem-24])
                            cust_order.remove(item2[rem-24])
                            q=cust_q.pop(rem_index)
                            cust_order_no.pop(rem_index)
                            cust_bill_1.pop(rem_index)
                            cust_bill_2.pop(rem_index)
                            cust_total-=q*item2_price[rem-24]
                            print("\t\tRemoved!")
                          else:
                            print("\t\tThis dish is not in your order! Enter 100 to try again.")

                      else:
                          print("\t\tWrong number! Enter 100 to try again.")

                      cl=input("\t\tClick Enter to go back")
                      clearscreen()
                      menu()
                    else:
                        print("\t\tYour haven't ordered yet!")
                        cl=input("\t\tClick Enter to go back")
                        clearscreen()
                        menu()


                  else:
                    x=int(input("\t\tWrong entry! Try again:\t"))
                    continue
                  x=input("\t\tEnter item number:")
                  if x.isdigit():
                    x=int(x)
                    continue
                  else:
                    cl=input("\n\t\tClick Enter restart")
                    clearscreen()
                    view_menu()


                if x==0:
                  a=input("\n\t\tClick Enter to print Bill:\t")
                  clearscreen()
                  print('*' *79)
                  print("\t\t\t\t\tBILL")
                  print('=' * 79)

                  print("{}\t\t\t\t\t{}\t\t{}\t{}".format(bill_output[0],bill_output[1],bill_output[2],bill_output[3]))
                  print("-"*79)

                  for i in range(len(cust_order)):
                    print("{}\t\t\t₹{}\t\t  {}\t\t₹{}".format(cust_order[i],cust_bill_1[i],cust_q[i],cust_bill_2[i]))
                  print('-' * 79)
                  print("\t\t\t\tGST (5%):\t₹",cust_total*0.05)
                  print("\t\t\t\tTotal:\t\t₹",(cust_total+cust_total*0.05))
                  print('=' * 79)
                  print('\t\t\t\tHave a good day!')
                  print('*' *79)
                  a=input("\n\t\tClick Enter to finish.")

                  clearscreen()
                  home()
              else:
                clearscreen()
                view_menu()
            else:
              clearscreen()
              home()


def main():                                  # MAIN FUNCTION
  print("\n\t\t\tORION")
  print("\t","="*38)
  print("\t\t      LOGIN PAGE")
  print("\t","-"*38)
  print()
  print("\t\t1. Customer Login")
  print("\t\t2. Restaurant Login")
  print("\n\t    Enter any other key to exit.\n")
  x=(input("\t\t Enter choice:  "))
  if x=='1':
    clearscreen()
    home()
  elif x=='2':
    clearscreen()
    management()
  else:
    clearscreen()
    y=input("\t\tExit?  (Y/N):  ")
    if y=="Y" or y=="y":
      clearscreen()
      print("\t\tGOODBYE")
    else:
      clearscreen()
      main()


def view_res():                           # FUNCTION TO VIEW RESERVATIONS AND FEEDBACK
  print("\t\t 1. View Reservations")
  print("\t\t 2. View Feedback")
  print("\t\t 3. Exit")
  x=input("\t\tEnter: ")
  clearscreen()
  if x=='3':
    main()
  elif x=='1':
      for i in dates.keys():
        a=dates[i]
        a=a.split('_')              # LIST CONTAINING SEVERAL TIMES OF SAME DATE
        print("\t\t",i,"- ",end="")
        for j in a:
          print(j,end=" ")
        print()
      a=input("\n\t\tEnter any key to exit. ")
      clearscreen()
      view_res()
  elif x=="2":
    for i in answers.keys():
      print("\t\t",questions[i-1],"\t",answers[i])
    a=input("\n\t\tEnter any key to exit")
    clearscreen()
    view_res()


def management():                   # RESTAURANT PASSWORD CHECKING
  password="restaurant@123"
  p=input("\t\tEnter Password:  ")
  ctr=1
  while ctr<4:
    if p!=password and ctr!=3:
      print("\t\tWRONG! TRY AGAIN")
      print("\t\t",3-ctr," tries remaining!")
      ctr+=1
    else:
      clearscreen()
      view_res()
      break
    p=input("\t\tEnter Password:  ")
  if ctr==3 and p!=password:
    print("\t\t3 Wrong Tries!")
    print("\n\t\tEXITING SYSTEM!")


clearscreen()
main()
